# %%
import _init_paths
from fast_rcnn.config import cfg
from fast_rcnn.test import im_detect
from fast_rcnn.nms_wrapper import nms
from utils.timer import Timer
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import scipy.io as sio
import caffe, os, sys, cv2
import os.path as osp
#import argparse

CLASSES = ('__background__', 'person')

NETS = {'vgg16': ('VGG16','vgg16_faster_rcnn_iter_30000.caffemodel'),
    'zf': ('ZF','zf_faster_rcnn_split4bronze_iter3w.caffemodel')}

# %%
def draw_detections(im, dets, image_name, thresh=0.5,colour=(0,0,255)):
    """Draw detected bounding boxes."""
    font = cv2.FONT_HERSHEY_SIMPLEX
    
    img_n=image_name.split('.')[0]
    inds = np.where(dets[:, -1] >= thresh)[0]
    
    if len(inds) == 0:
        print 'there is no person'
        return
    for i in inds:
        bbox = dets[i, :4]
        score = dets[i, -1]
        cv2.rectangle(im,(bbox[0],bbox[1]),(bbox[2],bbox[3]),colour,2)        
        #draw the confidence
        str3 =('{:.3f}').format(score)
        cv2.putText(im,str3,(bbox[0],bbox[1]), font, 1,colour,1,1)
            

def demo(net, image_name):
    """Detect object classes in an image using pre-computed object proposals."""

    # Load the demo image
    im_file = os.path.join(cfg.DATA_DIR, 'bronze-images', image_name)
    im = cv2.imread(im_file)
    
    out_dir = "/home/xyt/py-faster-rcnn/result_vis/result-bronze/" 
    
    # Detect all object classes and regress object bounds
    timer = Timer()
    timer.tic()
    scores, boxes = im_detect(net, im)
    timer.toc()
    print ('Detection took {:.3f}s for '
           '{:d} object proposals').format(timer.total_time, boxes.shape[0])

    # Visualize detections for each class
    CONF_THRESH = 0.5
    NMS_THRESH = 0.3
    cls_ind = 1 # because we skipped background
    cls_boxes = boxes[:, 4:8]
    cls_scores = scores[:, cls_ind]
    dets = np.hstack((cls_boxes,
                       cls_scores[:, np.newaxis])).astype(np.float32)
    
    draw_detections(im, dets, image_name, thresh=CONF_THRESH,colour=(0,255,0))
    
    keep = nms(dets, NMS_THRESH)
    dets = dets[keep, :]
    draw_detections(im, dets, image_name, thresh=CONF_THRESH,colour=(0,0,255))

    cv2.imwrite(out_dir+image_name, im)

# %%
    def add_path(path):
        if path not in sys.path:
            sys.path.insert(0, path)
    this_dir ='/home/xyt/py-faster-rcnn/tools/'

    # Add caffe to PYTHONPATH
    caffe_path = osp.join(this_dir, '..', 'caffe-fast-rcnn', 'python')
    add_path(caffe_path)

    # Add lib to PYTHONPATH
    lib_path = osp.join(this_dir, '..', 'lib')
    add_path(lib_path)

    cfg.TEST.RPN_POST_NMS_TOP_N=100
    cfg.TEST.HAS_RPN = True
    prototxt = os.path.join(cfg.MODELS_DIR,NETS['vgg16'][0],
                                'faster_rcnn_end2end', 'test.prototxt')
    caffemodel = os.path.join(cfg.DATA_DIR, 'trained_models',
                                 NETS['vgg16'][1])
    if not os.path.isfile(caffemodel):
        raise IOError(('{:s} not found.\nDid you run ./data/script/'
                       'fetch_faster_rcnn_models.sh?').format(caffemodel))

    #caffe.set_mode_cpu()
    caffe.set_mode_gpu()
    caffe.set_device(0)

    net = caffe.Net(prototxt, caffemodel, caffe.TEST)
    print '\n\nLoaded network {:s}'.format(caffemodel)

    # Warmup on a dummy image
    im = 128 * np.ones((300, 500, 3), dtype=np.uint8)
    for i in xrange(2):
        _, _= im_detect(net, im)
    
    for i in range(1,501):
         print '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~' 
         im_name=str(i)+".jpg"
          # Load the demo image
         print 'Demo for data/demo/{}'.format(im_name)
         demo(net,im_name)

    print 'done!'
# Out:
# Loaded network /home/xyt/py-faster-rcnn/data/trained_models/vgg16_faster_rcnn_iter_30000.caffemodel
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/1.jpg
# Detection took 1.071s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/2.jpg
# Detection took 1.071s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/3.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/4.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/5.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/6.jpg
# Detection took 1.052s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/7.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/8.jpg
# Detection took 1.051s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/9.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/10.jpg
# Detection took 1.044s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/11.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/12.jpg
# Detection took 1.055s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/13.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/14.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/15.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/16.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/17.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/18.jpg
# Detection took 1.051s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/19.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/20.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/21.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/22.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/23.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/24.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/25.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/26.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/27.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/28.jpg
# Detection took 1.054s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/29.jpg
# Detection took 1.043s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/30.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/31.jpg
# Detection took 1.051s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/32.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/33.jpg
# Detection took 1.062s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/34.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/35.jpg
# Detection took 1.044s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/36.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/37.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/38.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/39.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/40.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/41.jpg
# Detection took 1.041s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/42.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/43.jpg
# Detection took 1.062s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/44.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/45.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/46.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/47.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/48.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/49.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/50.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/51.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/52.jpg
# Detection took 1.044s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/53.jpg
# Detection took 1.067s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/54.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/55.jpg
# Detection took 1.053s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/56.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/57.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/58.jpg
# Detection took 1.059s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/59.jpg
# Detection took 1.051s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/60.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/61.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/62.jpg
# Detection took 1.042s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/63.jpg
# Detection took 1.052s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/64.jpg
# Detection took 1.054s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/65.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/66.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/67.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/68.jpg
# Detection took 1.064s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/69.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/70.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/71.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/72.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/73.jpg
# Detection took 1.043s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/74.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/75.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/76.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/77.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/78.jpg
# Detection took 1.051s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/79.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/80.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/81.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/82.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/83.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/84.jpg
# Detection took 1.052s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/85.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/86.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/87.jpg
# Detection took 1.059s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/88.jpg
# Detection took 1.064s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/89.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/90.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/91.jpg
# Detection took 1.051s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/92.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/93.jpg
# Detection took 1.051s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/94.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/95.jpg
# Detection took 1.052s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/96.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/97.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/98.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/99.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/100.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/101.jpg
# Detection took 1.044s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/102.jpg
# Detection took 1.053s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/103.jpg
# Detection took 1.043s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/104.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/105.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/106.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/107.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/108.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/109.jpg
# Detection took 1.044s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/110.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/111.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/112.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/113.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/114.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/115.jpg
# Detection took 1.044s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/116.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/117.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/118.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/119.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/120.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/121.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/122.jpg
# Detection took 1.043s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/123.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/124.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/125.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/126.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/127.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/128.jpg
# Detection took 1.044s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/129.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/130.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/131.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/132.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/133.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/134.jpg
# Detection took 1.051s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/135.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/136.jpg
# Detection took 1.051s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/137.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/138.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/139.jpg
# Detection took 1.053s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/140.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/141.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/142.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/143.jpg
# Detection took 1.053s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/144.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/145.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/146.jpg
# Detection took 1.044s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/147.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/148.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/149.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/150.jpg
# Detection took 1.043s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/151.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/152.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/153.jpg
# Detection took 1.067s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/154.jpg
# Detection took 1.065s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/155.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/156.jpg
# Detection took 1.043s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/157.jpg
# Detection took 1.044s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/158.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/159.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/160.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/161.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/162.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/163.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/164.jpg
# Detection took 1.101s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/165.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/166.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/167.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/168.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/169.jpg
# Detection took 1.044s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/170.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/171.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/172.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/173.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/174.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/175.jpg
# Detection took 1.052s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/176.jpg
# Detection took 1.051s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/177.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/178.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/179.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/180.jpg
# Detection took 1.043s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/181.jpg
# Detection took 1.055s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/182.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/183.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/184.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/185.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/186.jpg
# Detection took 1.051s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/187.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/188.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/189.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/190.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/191.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/192.jpg
# Detection took 1.056s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/193.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/194.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/195.jpg
# Detection took 1.052s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/196.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/197.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/198.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/199.jpg
# Detection took 1.044s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/200.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/201.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/202.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/203.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/204.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/205.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/206.jpg
# Detection took 1.051s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/207.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/208.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/209.jpg
# Detection took 1.059s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/210.jpg
# Detection took 1.052s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/211.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/212.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/213.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/214.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/215.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/216.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/217.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/218.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/219.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/220.jpg
# Detection took 1.042s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/221.jpg
# Detection took 1.051s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/222.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/223.jpg
# Detection took 1.055s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/224.jpg
# Detection took 1.048s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/225.jpg
# Detection took 1.044s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/226.jpg
# Detection took 1.047s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/227.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/228.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/229.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/230.jpg
# Detection took 1.045s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/231.jpg
# Detection took 1.050s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/232.jpg
# Detection took 1.046s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/233.jpg
# Detection took 1.044s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/234.jpg
# Detection took 1.049s for 100 object proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Demo for data/demo/235.jpg
